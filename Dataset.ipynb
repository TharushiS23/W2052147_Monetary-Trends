# %%
import pandas as pd

# %%
df1= pd.read_excel("monetaryexcel.xlsx")

# %%
df1.head()
# Out:
#         Date  Reserve Money (M0)  (a)  Broad Money (M2) (b)  \
# 0 1995-12-01                    78587                228536
# 1 1996-01-01                    77071                228090
# 2 1996-02-01                    79586                234199
# 3 1996-03-01                    82915                239178
# 4 1996-04-01                    80873                241893
#
#    Currency held by the Public  Demand Deposits held by the Public  \
# 0                        42199                               33019
# 1                        41074                               32709
# 2                        42317                               35123
# 3                        45066                               36730
# 4                        43480                               35998
#
#    Narrow Money (M1) \n(c)    \n (1) + (2)  \
# 0                                    75218
# 1                                    73783
# 2                                    77440
# ...

# %%
df1.dtypes
# Out:
# Date                                                         datetime64[ns]
# Reserve Money (M0)  (a)                                               int64
# Broad Money (M2) (b)                                                  int64
# Currency held by the Public                                           int64
# Demand Deposits held by the Public                                    int64
# Narrow Money (M1) \n(c)    \n (1) + (2)                               int64
# Time and Savings Deposits held by the Public                          int64
# Broad Money (M2b) \n(d)            \n (3) + (4)                       int64
# Net Foreign Assets of Monetary Authorities (e)                        int64
# Net Foreign Assets of Commercial Banks                                int64
# Net Foreign Assets (NFA) \n(5) + (6)                                  int64
# Net Credit granted to the Government by Central Bank                  int64
# ...

# %%
df1.isnull().sum()
# Out:
# Date                                                         0
# Reserve Money (M0)  (a)                                      0
# Broad Money (M2) (b)                                         0
# Currency held by the Public                                  0
# Demand Deposits held by the Public                           0
# Narrow Money (M1) \n(c)    \n (1) + (2)                      0
# Time and Savings Deposits held by the Public                 0
# Broad Money (M2b) \n(d)            \n (3) + (4)              0
# Net Foreign Assets of Monetary Authorities (e)               0
# Net Foreign Assets of Commercial Banks                       0
# Net Foreign Assets (NFA) \n(5) + (6)                         0
# Net Credit granted to the Government by Central Bank         0
# Net Credit granted to the Government by Commercial Banks     0
# Net Credit granted to the Government (NCG)\n(8) + (9)        0
# Credit granted to Public Corporations by Commercial Banks    0
# ...

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %%
df1.to_csv('Monetary_stats_1995-2025.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df1.to_csv('Monetary_stats_1995-2025.csv', index=False)
#
# File c:\Users\tharu\anaconda3\envs\Streamlit\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 349 entries, 0 to 348
# Data columns (total 20 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Date                                                       349 non-null    datetime64[ns]
#  1   Reserve Money (M0)  (a)                                    349 non-null    int64
#  2   Broad Money (M2) (b)                                       349 non-null    int64
#  3   Currency held by the Public                                349 non-null    int64
#  4   Demand Deposits held by the Public                         349 non-null    int64
#  5   Narrow Money (M1)
# (c)
#  (1) + (2)                      349 non-null    int64
#  6   Time and Savings Deposits held by the Public               349 non-null    int64
#  7   Broad Money (M2b)
# (d)
#  (3) + (4)              349 non-null    int64
# ...

# %%
df1['Date'] = df1['Date'].astype('date64[pyarrow]')

# %%
df1.head()
# Out:
#         Date  Reserve Money (M0)  (a)  Broad Money (M2) (b)  \
# 0 1995-12-01                    78587                228536
# 1 1996-01-01                    77071                228090
# 2 1996-02-01                    79586                234199
# 3 1996-03-01                    82915                239178
# 4 1996-04-01                    80873                241893
#
#    Currency held by the Public  Demand Deposits held by the Public  \
# 0                        42199                               33019
# 1                        41074                               32709
# 2                        42317                               35123
# 3                        45066                               36730
# 4                        43480                               35998
#
#    Narrow Money (M1) \n(c)    \n (1) + (2)  \
# 0                                    75218
# 1                                    73783
# 2                                    77440
# ...

# %%
df1.dtypes
# Out:
# Date                                                         date64[ms][pyarrow]
# Reserve Money (M0)  (a)                                                    int64
# Broad Money (M2) (b)                                                       int64
# Currency held by the Public                                                int64
# Demand Deposits held by the Public                                         int64
# Narrow Money (M1) \n(c)    \n (1) + (2)                                    int64
# Time and Savings Deposits held by the Public                               int64
# Broad Money (M2b) \n(d)            \n (3) + (4)                            int64
# Net Foreign Assets of Monetary Authorities (e)                             int64
# Net Foreign Assets of Commercial Banks                                     int64
# Net Foreign Assets (NFA) \n(5) + (6)                                       int64
# Net Credit granted to the Government by Central Bank                       int64
# ...

# %%
df1.sort_values('Date',inplace=True)

# %%
df1['Date']
# Out:
# 0      1995-12-01
# 1      1996-01-01
# 2      1996-02-01
# 3      1996-03-01
# 4      1996-04-01
#           ...
# 344    2024-08-01
# 345    2024-09-01
# 346    2024-10-01
# 347    2024-11-01
# 348    2024-12-01
# Name: Date, Length: 349, dtype: date64[ms][pyarrow]

# %%
df1.to_csv("Monetary data 1996-2025")
